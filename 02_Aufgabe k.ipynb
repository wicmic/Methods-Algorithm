# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.cluster import KMeans

# %%
data = np.loadtxt('data/wine.dat', delimiter=',')

# %%
plt.scatter(data[:,0], data[:,1], c=data[:,2])
plt.show()

# %%
x_data = data[:,:2]   # Spalten 0 und 1 --> Koordinaten
y_data = data[:,2]    # Spalte 2 --> korrekte Klassifikation
inert = []
for k in range(1,11): #Anzahl k anpassen, wird für jedes k in Range durchgeführt
  model = KMeans(n_clusters=k)
  model.fit(x_data)
  inert.append(model.inertia_)
# Out:
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jacqu\OneDrive\Dokumente\MSC DV\Python\Python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Visualisierung
x = np.linspace(1, 10, 10)
plt.plot(x, inert, 'b-')
plt.plot(x, inert, 'bo')
plt.show()

# %%
model = KMeans(n_clusters=3) #Anzahl Cluster und Iteration (Anzahl bis Abbruch) anpassen
y_pred = model.fit_predict(x_data) #Vorhersage bestimmen
# Out:
# C:\Users\michi\OneDrive\MSC DV\Python\venv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(data[:,0], data[:,1], c=y_pred)
plt.show()

# %%
#bestes k
data = np.loadtxt('data/smp_data.dat', delimiter=',')
x_data = data[:,0].reshape((-1,1))
y_data = data[:,1]
from sklearn.neighbors import KNeighborsRegressor as knr
model = knr()
model.fit(x_data, y_data)

from sklearn.metrics import r2_score
for k in range(1,16):
    model = knr(k)
    model.fit(x_data, y_data)
    y_pred = model.predict(x_data)
    print(k, ":", r2_score(y_data, y_pred))
# Out:
# 1 : 0.6246482144982819
# 2 : 0.7862567099967751
# 3 : 0.792704577432517
# 4 : 0.7920644178942171
# 5 : 0.7954526029533308
# 6 : 0.7947186903321566
# 7 : 0.7917421360215728
# 8 : 0.7817331928824984
# 9 : 0.7820701385272495
# 10 : 0.7740986562673406
# 11 : 0.7748944914201004
# 12 : 0.7658630272930738
# 13 : 0.7605760241489894
# 14 : 0.7667498417414382
# 15 : 0.7611215184737035

# %%
x = np.linspace(1,11,50)

# %%
model = knr(5)
model.fit(x_data, y_data)
y = model.predict(x.reshape((-1,1)))

# %%
plt.plot(x_data, y_data, "ro")
plt.plot(x, y, "b-")
plt.show()
